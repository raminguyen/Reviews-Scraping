# %% [markdown]
# # Scraping Reviews from Trustpilot for Electricity Providers in Ireland
#
# ## Description
#
# The provided Python script is designed to scrape customer reviews from Trustpilot for specific electricity providers in Ireland, such as Electric Ireland and Bord Gais Energy. The script gathers various details about each review, including the username, total reviews by the user, location, date of the review, content of the review, and the rating given. Here’s an overview of the process:
#
# 1. **Importing Necessary Libraries:**
#    - `requests` for making HTTP requests to the Trustpilot website.
#    - `BeautifulSoup` from `bs4` for parsing HTML content.
#    - `pandas` for creating and manipulating data in a DataFrame.
#    - `files` from `google.colab` for downloading the resulting Excel file.
#    - `datetime` for formatting the date.
#
# 2. **Helper Functions:**
#    - `soup2list(src, list_, attr=None)`: Extracts text or attribute values from HTML elements and appends them to a list.
#    - `format_date(date_str)`: Converts the `datetime` attribute from the `time` elements to a more readable date format.
#
# 3. **Defining Lists to Store Scraped Data:**
#    - Several lists (`users`, `userReviewNum`, `ratings`, `locations`, `dates`, `reviews`) are initialized to store the respective details of each review.
#
# 4. **Specifying the Range of Pages to Scrape:**
#    - Variables `from_page` and `to_page` define the range of pages to scrape reviews from (e.g., pages 1 to 6).
#
# 5. **Scraping Reviews:**
#    - A loop iterates over the specified range of pages.
#    - For each page, an HTTP GET request is made to the Trustpilot review page for the specified company.
#    - The HTML content of the page is parsed using `BeautifulSoup`.
#    - Various details (username, total reviews, location, date, rating, and review content) are extracted using the helper function `soup2list` and appended to the respective lists.
#    - A sleep interval is added between requests to avoid being throttled by the server.
#
# 6. **Ensuring Data Consistency:**
#    - All lists are extended to have the same length by padding them with empty values if necessary. This ensures that the DataFrame can be created without any issues.
#
# 7. **Creating a DataFrame:**
#    - A pandas DataFrame is created using the scraped data, with columns for each detail (Username, Total reviews, Location, Date, Content, Rating).
#
# 8. **Saving and Downloading the Data:**
#    - The DataFrame is saved as an Excel file (`.xlsx`).
#    - The Excel file is then downloaded to the local system using `files.download`.
#
# This script automates the process of collecting and saving customer reviews from Trustpilot, making it easier to analyze feedback for different electricity providers in Ireland.

# %%
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

def soup2list(src, list_, attr=None):
    if attr:
        for val in src:
            list_.append(val[attr])
    else:
        for val in src:
            list_.append(val.get_text())

def format_date(date_str):
    date_obj = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%fZ")
    return date_obj.strftime("%B %d, %Y")

users = []
userReviewNum = []
ratings = []
locations = []
dates = []
reviews = []

from_page = 1
to_page = 6
company = 'www.bordgaisenergy.ie'

for i in range(from_page, to_page+1):
    result = requests.get(f"https://www.trustpilot.com/review/{company}?page={i}")
    soup = BeautifulSoup(result.content, 'html.parser')

    soup2list(soup.find_all('span', {'class': 'typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}), users)
    soup2list(soup.find_all('span', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), userReviewNum)
    soup2list(soup.find_all('span', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), locations)
    
    date_elements = soup.find_all('time', {'datetime': True})
    for date_elem in date_elements:
        dates.append(format_date(date_elem['datetime']))
    
    soup2list(soup.find_all('div', {'class': 'styles_reviewHeader__iU9Px'}), ratings, attr='data-service-review-rating')
    soup2list(soup.find_all('p', {'class': 'typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn'}), reviews)

    sleep(1)  # To avoid throttling

# Ensure all lists are of the same length
max_len = max(len(users), len(userReviewNum), len(locations), len(dates), len(ratings), len(reviews))

users.extend([''] * (max_len - len(users)))
userReviewNum.extend([''] * (max_len - len(userReviewNum)))
locations.extend([''] * (max_len - len(locations)))
dates.extend([''] * (max_len - len(dates)))
ratings.extend([''] * (max_len - len(ratings)))
reviews.extend([''] * (max_len - len(reviews)))

review_data = pd.DataFrame(
{
   'Username': users,
   'Total reviews': userReviewNum,
   'Location': locations,
   'Date': dates,
   'Content': reviews,
   'Rating': ratings
})

# %% [markdown]
# # Output

# %%
review_data.head(50)
# Out:
#                 Username Total reviews     Location               Date  \
# 0         Judith Lawless   364 reviews  364 reviews      June 10, 2024
# 1                Katie B   455 reviews  455 reviews      June 11, 2024
# 2                   Anne   475 reviews  475 reviews      June 04, 2024
# 3         Terri McCarthy      1 review     1 review      June 05, 2024
# 4           Amir Moshari     3 reviews    3 reviews       May 31, 2024
# 5          Eoghan Murphy     7 reviews    7 reviews      June 11, 2024
# 6         Frances McHugh     2 reviews    2 reviews      June 10, 2024
# 7            Dušan Balog     2 reviews    2 reviews      June 11, 2024
# 8                  Niall     2 reviews    2 reviews       May 20, 2024
# 9                     Jo     4 reviews    4 reviews       May 20, 2024
# 10       Marjorie Burke.      1 review     1 review       May 21, 2024
# 11         Edel Williams      1 review     1 review       May 28, 2024
# 12           Paul Perrin      1 review     1 review     April 30, 2024
# 13           hilda kelly    11 reviews   11 reviews       May 03, 2024
# 14        Connor Donohue     2 reviews    2 reviews       May 07, 2024
# 15           Beth McLeod     5 reviews    5 reviews       May 08, 2024
# 16                 Kevin     2 reviews    2 reviews     April 21, 2024
# 17     Terrance Monteiro     7 reviews    7 reviews     April 24, 2024
# 18       Gabriela Duarte      1 review     1 review     April 11, 2024
# 19      Darragh O'Connor     2 reviews    2 reviews     April 17, 2024
# 20        Scammed victim      1 review     1 review       May 27, 2024
# 21          Sarah Hayden      1 review     1 review       May 28, 2024
# 22                 paddy      1 review     1 review       May 21, 2024
# 23            Les Cooper   364 reviews  364 reviews       May 28, 2024
# 24        Maurice Kerley   455 reviews  455 reviews     April 17, 2024
# 25     Michael Stanbrook   475 reviews  475 reviews     April 17, 2024
# 26         Bernie  Dunne     2 reviews    2 reviews       May 02, 2024
# 27           Mary Clarke      1 review     1 review       May 03, 2024
# 28            Evren Onem      1 review     1 review  February 27, 2024
# 29        Katrina Mackey     2 reviews    2 reviews       May 10, 2024
# 30            M. Higgins    19 reviews   19 reviews       May 15, 2024
# 31                Noirin     2 reviews    2 reviews      June 07, 2024
# 32              Customer      1 review     1 review      June 11, 2024
# 33          Richard Lowe      1 review     1 review       May 02, 2024
# 34         Brian Mckenna     2 reviews    2 reviews       May 03, 2024
# 35         Kevin Moloney      1 review     1 review     April 17, 2024
# 36                Fran N     5 reviews    5 reviews     April 17, 2024
# 37             Brian Fox     3 reviews    3 reviews     March 08, 2024
# 38          Conor Hurley     3 reviews    3 reviews     April 10, 2024
# 39        Ronan Cahalane     2 reviews    2 reviews     April 29, 2024
# 40                   Una     8 reviews    8 reviews     April 11, 2024
# 41                 Maria      1 review     1 review     April 17, 2024
# 42                  Tony     2 reviews    2 reviews  November 06, 2023
# 43            damo brien     2 reviews    2 reviews     April 18, 2024
# 44         sandra vlasec     4 reviews    4 reviews     April 18, 2024
# 45        Dean McInerney    15 reviews   15 reviews  February 16, 2023
# 46                   Kmt   364 reviews  364 reviews  December 04, 2023
# 47                  Prem   455 reviews  455 reviews  November 16, 2023
# 48  Ewelina .Niznikowska   475 reviews  475 reviews       May 02, 2024
# 49        Jonathan Flack     5 reviews    5 reviews       May 03, 2024
#
#                                               Content Rating
# 0   I have a BGE annual service plan for my two bo...      5
# 1   The worst company I’ve come across in my life!...      1
# 2   My boiler broke down. In less than 24 hours th...      5
# 3   Easy to deal with, simple and quick process to...      5
# 4   DON'T WASTE YOUR MONEY by ordering a service b...      1
# 5   Have a PAYG electricity meter with BGE in the ...      1
# 6   Bord Gais need to do something about their ser...      1
# 7   Worst company ever here in ireland i was calli...      1
# 8   Signed up for the home EV charger deal. Its wr...      1
# 9   Stay away to avoid stress and disappointment; ...      1
# 10  Booked my boiler service on line. I was regula...      5
# 11  I'm currently looking to change providers, as ...      1
# 12  Worst customer service. I have paid my bill by...      3
# 13  I have my boiler cleaned every year with Denny...      5
# 14  I do not like Bord Gais as an organization, I ...      1
# 15  Robert was fantastic, really lovely and easy. ...      5
# 16  Excellent service carried out after engineer s...      5
# 17  I wish there were an option for 0 stars. This ...      1
# 18  UPDATE: my issue has finally been resolved aft...      1
# 19  Shady, slow, unhelpful. Customer servie is a j...      1
# 20  Horrendous - I signed up to the Boiler 365 con...      1
# 21  Just had Ross out balancing my radiators as it...      5
# 22  I have a level pay contract with BGE. They hav...      1
# 23  Very easy to book the service after receiving ...      5
# 24  Worst services company ever. No customer suppo...      1
# 25  No show cancellation a few hours before the ap...      1
# 26  Stay well away from this company, they are an ...      1
# 27  Excellent and timely callout. No fuss or upsel...      5
# 28  Wished I'd read the boiler service reviews her...      1
# 29  Bord gais were underestimating my bill they cl...      1
# 30  Gas boiler service. Great technician shows up,...      5
# 31  Don't use Bord Gais for your electricity provi...      1
# 32  I just contacted bord gais to close my account...      5
# 33  An absolute horrible company to deal with and ...      1
# 34  Very poor service... The service engineer call...      1
# 35  Eventually got through to a member of customer...      1
# 36  I am at a loss as to why Bord Gais energy have...      1
# 37  I started a tenancy with Dublin city council, ...      1
# 38  I would advise anyone to stay miles away from ...      1
# 39  Absolutely appalling customer service.Bill was...      1
# 40  ABG customer (duel fuel), currently out of con...      1
# 41  I attended Alladin last Thursday 21 st March t...      5
# 42  Extremely difficult to deal with this energy p...      1
# 43  I'm judging them on my experience when I was l...      1
# 44  Booked boiler service online, paid in full, ph...      1
# 45  WORST energy company in the country! Steer wel...      1
# 46  Its no wonder they are getting a one start on ...      1
# 47  The worst gas provider in Ireland and the worl...      1
# 48  Avoid by all means! We have moved to a differe...      1
# 49  Paid for a discounted boiler service and surpr...      1
