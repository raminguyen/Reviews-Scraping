# %% [markdown]
# # Scraping Reviews from Trustpilot for Electricity Providers in Ireland
#
# ## Description
#
# The provided Python script is designed to scrape customer reviews from Trustpilot for specific electricity providers in Ireland, such as Electric Ireland and Bord Gais Energy. The script gathers various details about each review, including the username, total reviews by the user, location, date of the review, content of the review, and the rating given. Here’s an overview of the process:
#
# 1. **Importing Necessary Libraries:**
#    - `requests` for making HTTP requests to the Trustpilot website.
#    - `BeautifulSoup` from `bs4` for parsing HTML content.
#    - `pandas` for creating and manipulating data in a DataFrame.
#    - `files` from `google.colab` for downloading the resulting Excel file.
#    - `datetime` for formatting the date.
#
# 2. **Helper Functions:**
#    - `soup2list(src, list_, attr=None)`: Extracts text or attribute values from HTML elements and appends them to a list.
#    - `format_date(date_str)`: Converts the `datetime` attribute from the `time` elements to a more readable date format.
#
# 3. **Defining Lists to Store Scraped Data:**
#    - Several lists (`users`, `userReviewNum`, `ratings`, `locations`, `dates`, `reviews`) are initialized to store the respective details of each review.
#
# 4. **Specifying the Range of Pages to Scrape:**
#    - Variables `from_page` and `to_page` define the range of pages to scrape reviews from (e.g., pages 1 to 6).
#
# 5. **Scraping Reviews:**
#    - A loop iterates over the specified range of pages.
#    - For each page, an HTTP GET request is made to the Trustpilot review page for the specified company.
#    - The HTML content of the page is parsed using `BeautifulSoup`.
#    - Various details (username, total reviews, location, date, rating, and review content) are extracted using the helper function `soup2list` and appended to the respective lists.
#    - A sleep interval is added between requests to avoid being throttled by the server.
#
# 6. **Ensuring Data Consistency:**
#    - All lists are extended to have the same length by padding them with empty values if necessary. This ensures that the DataFrame can be created without any issues.
#
# 7. **Creating a DataFrame:**
#    - A pandas DataFrame is created using the scraped data, with columns for each detail (Username, Total reviews, Location, Date, Content, Rating).
#
# 8. **Saving and Downloading the Data:**
#    - The DataFrame is saved as an Excel file (`.xlsx`).
#    - The Excel file is then downloaded to the local system using `files.download`.
#
# This script automates the process of collecting and saving customer reviews from Trustpilot, making it easier to analyze feedback for different electricity providers in Ireland.

# %%
from time import sleep
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

def soup2list(src, list_, attr=None):
    if attr:
        for val in src:
            list_.append(val[attr])
    else:
        for val in src:
            list_.append(val.get_text())

def format_date(date_str):
    date_obj = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%fZ")
    return date_obj.strftime("%B %d, %Y")

def scrape_reviews(company, from_page=1, to_page=6):
    users = []
    userReviewNum = []
    ratings = []
    locations = []
    dates = []
    reviews = []

    for i in range(from_page, to_page+1):
        result = requests.get(f"https://www.trustpilot.com/review/{company}?page={i}")
        soup = BeautifulSoup(result.content, 'html.parser')

        soup2list(soup.find_all('span', {'class': 'typography_heading-xxs__QKBS8 typography_appearance-default__AAY17'}), users)
        soup2list(soup.find_all('span', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), userReviewNum)
        soup2list(soup.find_all('span', {'class': 'typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l'}), locations)

        date_elements = soup.find_all('time', {'datetime': True})
        for date_elem in date_elements:
            dates.append(format_date(date_elem['datetime']))

        soup2list(soup.find_all('div', {'class': 'styles_reviewHeader__iU9Px'}), ratings, attr='data-service-review-rating')
        soup2list(soup.find_all('p', {'class': 'typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn'}), reviews)

        sleep(1)  # To avoid throttling

    # Ensure all lists are of the same length
    max_len = max(len(users), len(userReviewNum), len(locations), len(dates), len(ratings), len(reviews))

    users.extend([''] * (max_len - len(users)))
    userReviewNum.extend([''] * (max_len - len(userReviewNum)))
    locations.extend([''] * (max_len - len(locations)))
    dates.extend([''] * (max_len - len(dates)))
    ratings.extend([''] * (max_len - len(ratings)))
    reviews.extend([''] * (max_len - len(reviews)))

    review_data = pd.DataFrame(
        {
            'Username': users,
            'Total reviews': userReviewNum,
            'Location': locations,
            'Date': dates,
            'Content': reviews,
            'Rating': ratings
        }
    )

    return review_data

companies = ['www.mexipass.com', 'tripinsure101.com']
all_reviews = pd.DataFrame()

for company in companies:
    reviews = scrape_reviews(company)
    reviews['Company'] = company
    all_reviews = pd.concat([all_reviews, reviews], ignore_index=True)

# %% [markdown]
# # Output

# %%
len(all_reviews)
# Out:
# 138

# %%
all_reviews.head(50)
# Out:
#                                             Username Total reviews  \
# 0                                       Blanca  Haro  3.1K reviews
# 1                                    Amalia Cardenas  1.2K reviews
# 2                                     Martin Johnson   25K reviews
# 3                                      Thomas Gibson     2 reviews
# 4                                    Sheba Insurance      1 review
# 5                                     Carol A. Burns     2 reviews
# 6                                          see above      1 review
# 7                                         Michelle A      1 review
# 8                                    Jose F. Arizola     2 reviews
# 9                                  Guillermo Jimenez      1 review
# 10                                         Jeff Moro     2 reviews
# 11                                  Rebecca Redhouse     2 reviews
# 12                                 Elizabeth  Sabata     3 reviews
# 13                                     Linda Jimenez      1 review
# 14                                      Shannon  Cue     3 reviews
# 15                                   Rafael Martinez      1 review
# 16                                Melissa T. Bolanos      1 review
# 17                Hector from HRC Insurance Services      1 review
# 18                                    Tricia Pendrez     2 reviews
# 19                                       Jean Nestor      1 review
# 20                               Perla G. Ruiz-Lopez     7 reviews
# 21  Rafael from Rafael Suarez Insurance Agency, Inc.      1 review
# 22                                   Lydia Rodriguez     4 reviews
# 23                                    Mary L. Garcia  3.1K reviews
# 24                                  Mariela Martinez  1.2K reviews
# 25                                       Rowena Phan   25K reviews
# 26                                    Irma B Noriega      1 review
# 27                                     Dorothy Boles    10 reviews
# 28                                          customer      1 review
# 29                                     Karlyn  Stern      1 review
# 30                Karen from Forrest Evans Insurance      1 review
# 31                                        Donna Lynn      1 review
# 32                                    Carmella  Rios      1 review
# 33                                            Kartik      1 review
# 34                   Norma from Norma Mendoza Agency     2 reviews
# 35                                       Aida Rivera      1 review
# 36                                        Rosie Diaz     3 reviews
# 37                                             pedro      1 review
# 38                                          Emily M.     5 reviews
# 39                                   Vicky  Gonzalez      1 review
# 40                                  Melissa Harrison     2 reviews
# 41                                         Scarlette      1 review
# 42                                  Sean  R. Weiland      1 review
# 43                              Maite Farrant-Licata     4 reviews
# 44                                     Sharie Racine     2 reviews
# 45                                    Patty Martinez     2 reviews
# 46                                     Naeem Munawar  3.1K reviews
# 47                                     Helga J Munoz  1.2K reviews
# 48                                             Terry   25K reviews
# 49                                Melissa  Robertson     3 reviews
#
#         Location                Date  \
# 0   3.1K reviews       June 24, 2024
# 1   1.2K reviews       June 26, 2024
# 2    25K reviews       June 10, 2024
# 3      2 reviews       June 24, 2024
# 4       1 review       June 16, 2024
# 5      2 reviews       June 06, 2024
# 6       1 review        May 31, 2024
# 7       1 review       June 22, 2024
# 8      2 reviews       June 20, 2024
# 9       1 review       June 15, 2024
# 10     2 reviews        May 29, 2024
# 11     2 reviews       June 01, 2024
# 12     3 reviews       June 17, 2024
# 13      1 review       June 11, 2024
# 14     3 reviews       June 24, 2024
# 15      1 review       June 20, 2024
# 16      1 review      March 25, 2024
# 17      1 review       June 10, 2024
# 18     2 reviews       June 06, 2024
# 19      1 review      April 23, 2024
# 20     7 reviews      March 29, 2024
# 21      1 review   December 22, 2023
# 22     4 reviews       June 11, 2024
# 23  3.1K reviews      March 30, 2024
# 24  1.2K reviews       June 08, 2024
# 25   25K reviews     August 15, 2023
# 26      1 review        May 30, 2024
# 27    10 reviews        May 20, 2024
# 28      1 review        May 23, 2024
# 29      1 review      April 06, 2024
# 30      1 review      April 20, 2024
# 31      1 review   November 15, 2023
# 32      1 review    January 25, 2024
# 33      1 review       June 19, 2024
# 34     2 reviews   November 29, 2023
# 35      1 review    October 06, 2023
# 36     3 reviews    January 29, 2024
# 37      1 review  September 08, 2023
# 38     5 reviews   November 13, 2023
# 39      1 review   December 21, 2023
# 40     2 reviews   February 19, 2024
# 41      1 review   November 20, 2023
# 42      1 review        May 29, 2024
# 43     4 reviews       June 18, 2024
# 44     2 reviews   December 12, 2023
# 45     2 reviews  September 15, 2023
# 46  3.1K reviews    October 29, 2023
# 47  1.2K reviews       June 22, 2024
# 48   25K reviews  September 20, 2023
# 49     3 reviews   December 05, 2023
#
#                                               Content Rating
# 0   had a couple of questions regarding coverage. ...      5
# 1   i have been appointed with Mexipass for many y...      5
# 2   Other than the systems to update, change or re...      5
# 3   MexiPass is so easy to work with and team is g...      5
# 4   The website platform is very easy to use and u...      5
# 5   Your online quoting platform is very easy and ...      5
# 6   Your website is user friendly and it helps!  B...      5
# 7   Great customer service!  As insurance agents, ...      5
# 8   Wow more easy to process applications and very...      5
# 9   Great Value!Easy to work with, good pricing.Co...      5
# 10  The entire process of quoting homeowner & auto...      5
# 11  Mexipass is always a pleasant experience. Cust...      5
# 12  Easy quoting and easy to do the application an...      5
# 13  The process for renewing a policy is very easy...      5
# 14  I like the new format of the portal. It is ver...      5
# 15            The theft deductible is way too high!        3
# 16  I don't use Mexipass very often, but when I do...      5
# 17  Great Customer Service every time we call mexi...      5
# 18  Received renewal terms in a timely manner and ...      5
# 19  I was able to get a quote for a vehicle that n...      5
# 20  My experience with mexipass has been wonderful...      3
# 21  I have done business with Mexipass for about 1...      3
# 22  I called tech support and the person who help ...      5
# 23  Very informative and easy to use especially th...      5
# 24  Quick and easy to quote ! Also provided great ...      5
# 25  Ened made it easy to get a revised quote with ...      5
# 26  We need a company rep that come to visit to up...      3
# 27  The MexiPass quoting/issuing website is very u...      5
# 28  Mexipass is a user friendly website, its alway...      5
# 29  Jorge and Ben made this whole quoting and bind...      5
# 30  Personnel are always friendly and helpful, nev...      5
# 31  The system is pretty easy to use, but it would...      4
# 32  The site is super easy to get quotes from, ret...      5
# 33  Mexipass was very easy to get a quote online, ...      5
# 34  The transition from the old system to the new ...      5
# 35  Your Web page was so clear and easy to follow ...      5
# 36  Love using Mexipass for coverage. It's super e...      5
# 37  The quoting and renewal process is easy on the...      5
# 38  My clients are happy with the company that doe...      4
# 39  Quick renewal responses with Ened makes the wh...      5
# 40  Benjamin & Jorge were very responsive to all m...      5
# 41  Ease of use is the best compliment I can give ...      5
# 42  `Thank you to the underwriter, (Ened) who has ...      5
# 43  Our underwriter Ened is very responsive. It wa...      5
# 44  Very easy to deal with,  never experienced lon...      5
# 45   Easy to renew with previous policy's information      5
# 46  Such a great platform, user friendly I love th...      5
# 47  Easy thourough app process from start to finis...      5
# 48  It is a very easy process when writing a Mexip...      5
# 49  simple rating and great customer service-  rat...      5
